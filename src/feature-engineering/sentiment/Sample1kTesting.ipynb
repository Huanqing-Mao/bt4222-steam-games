# %%
import pandas as pd
import numpy as np

# %%
reviews = pd.read_csv("../../datasets/english_reviews.csv")

# %%
reviews
# Out:
#         reviewid           playerid   gameid  \
# 0         639544  76561198028706627   393380
# 1         639547  76561198272817436      730
# 2         639571  76561198111259840  1476680
# 3         639583  76561198164012532   244210
# 4         639671  76561198979874677   739630
# ...          ...                ...      ...
# 303866    639524  76561198985274668      440
# 303867    639526  76561198985274668   271590
# 303868    639528  76561198985274668      550
# 303869    639529  76561198985274668      730
# 303870    639535  76561199401415130      730
#
#                                                    review  helpful  funny  \
# 0       ---{ Graphics }---☐ You forget what reality is...        0      0
# 1                         ONE OF THE GAMES I COME BACK TO        2      0
# 2       I love this game!Of course it is currently in ...        5      0
# 3       only purchase if using a sim wheel setup with ...        0      0
# ...

# %%
reviews_1k = reviews.sample(n=1000,random_state=42)

# %%
reviews_1k.to_csv("../../datasets/english_reviews_1k.csv", index=False)
